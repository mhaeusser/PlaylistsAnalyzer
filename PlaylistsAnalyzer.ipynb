# %%
# loads contents of a url
from urllib.request import urlopen 
import re
def read_url(url): 
    return urlopen(url).read().decode()

# %%
# from a html playlist, extracts the actual playlists which must be inside '<!-- Start -->' and '<!-- End -->'
def extract_raw_playlists(text):
    start = text.index('<!-- Start -->')
    end = text.index('<!-- End -->')
    raw = text[start+14 : end]
    return raw

# %%
def replace_junk(text):
    text = text.replace('&amp;', '&')
    text = text.replace('&#8211;', '-')
    text = text.replace('&#8216;', "'")
    text = text.replace('&#8217;', "'")
    text = text.replace('- <i>Jingle</i>', '')
    return text

# %%
def norm_linebreaks(text):
    #text = text.replace('</p>\n<p>', '<br/>')
    text = text.replace('<br />', '\n')
    text = text.replace('<br/>', '\n')
    text = text.replace('<p>', '')
    text = text.replace('</p>', '')
    text = text.replace('\n\n', '\n')
    return text

# %%
text = read_url('http://ska.one/playlists/playlists-2003/')
text
# Out:
# '<!DOCTYPE html>\n<html lang="de-DE">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Playlists 2003 | File Under Ska</title>\n<link rel="profile" href="http://gmpg.org/xfn/11">\n<link rel="pingback" href="http://ska.one/xmlrpc.php">\n\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="File Under Ska &raquo; Feed" href="http://ska.one/feed/" />\n<link rel="alternate" type="application/rss+xml" title="File Under Ska &raquo; Kommentar-Feed" href="http://ska.one/comments/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/2.4\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/2.4\\/svg\\/","svgExt":".svg","source":{"concatemoji":"http:\\/\\/ska.one\\/wp-includes\\/js\\/wp-emoji-release.min.js?ve
# ...

# %%
text = extract_raw_playlists(text)
text
# Out:
# '</p>\n<p>Playlist 29.12.2003:</p>\n<p>&#8211; Bad Manners: This Is Ska<br />\n&#8211; Soulfood International: T&#8217;N&#8217;T<br />\n&#8211; Mad Caddies: Econoline<br />\n&#8211; Catch 22: Hard To Impress<br />\n&#8211; Eläkeläiset: Humppa<br />\n&#8211; Ska-P: Welcome To Hell<br />\n&#8211; Suggs: No More Alcohol<br />\n&#8211; The Selecter: Carry Go Bring Home<br />\n&#8211; Surfits: Straight At The Edge Badge<br />\n&#8211; Skaos: Better Beware<br />\n&#8211; General Rudie: So Much<br />\n&#8211; Two Thousand Flushes: Mi Hamster Esta Muerto<br />\n&#8211; Tschiggedab: Tschiggedab<br />\n&#8211; Edje Ska: Problemen In Minnen Hof<br />\n&#8211; The Robustos: No Strangers Here<br />\n&#8211; The Specials: You&#8217;re Wondering Now</p>\n<p>Playlist 22.12.2003:</p>\n<p>&#8211; The Ethopians: Train To Skaville<br />\n&#8211; Maroon Town: Pound To The Dollar<br />\n&#8211; Court Jester&#8217;s Crew: The Mysterious Voyage of Dillfried die Maus<br />\n&#8211; Yellow Umbrella: Days Are 
# ...

# %%
text = replace_junk(text)
text
# Out:
# '</p>\n<p>Playlist 29.12.2003:</p>\n<p>- Bad Manners: This Is Ska<br />\n- Soulfood International: T\'N\'T<br />\n- Mad Caddies: Econoline<br />\n- Catch 22: Hard To Impress<br />\n- Eläkeläiset: Humppa<br />\n- Ska-P: Welcome To Hell<br />\n- Suggs: No More Alcohol<br />\n- The Selecter: Carry Go Bring Home<br />\n- Surfits: Straight At The Edge Badge<br />\n- Skaos: Better Beware<br />\n- General Rudie: So Much<br />\n- Two Thousand Flushes: Mi Hamster Esta Muerto<br />\n- Tschiggedab: Tschiggedab<br />\n- Edje Ska: Problemen In Minnen Hof<br />\n- The Robustos: No Strangers Here<br />\n- The Specials: You\'re Wondering Now</p>\n<p>Playlist 22.12.2003:</p>\n<p>- The Ethopians: Train To Skaville<br />\n- Maroon Town: Pound To The Dollar<br />\n- Court Jester\'s Crew: The Mysterious Voyage of Dillfried die Maus<br />\n- Yellow Umbrella: Days Are Numbered<br />\n- The Riffs: Monday Morning<br />\n- The Busters: Friday On My Mind<br />\n- Laurel Aitken: Going Back To The Frontline<br /
# ...

# %%
text = norm_linebreaks(text)
text
# Out:
# '\nPlaylist 29.12.2003:\n- Bad Manners: This Is Ska\n- Soulfood International: T\'N\'T\n- Mad Caddies: Econoline\n- Catch 22: Hard To Impress\n- Eläkeläiset: Humppa\n- Ska-P: Welcome To Hell\n- Suggs: No More Alcohol\n- The Selecter: Carry Go Bring Home\n- Surfits: Straight At The Edge Badge\n- Skaos: Better Beware\n- General Rudie: So Much\n- Two Thousand Flushes: Mi Hamster Esta Muerto\n- Tschiggedab: Tschiggedab\n- Edje Ska: Problemen In Minnen Hof\n- The Robustos: No Strangers Here\n- The Specials: You\'re Wondering Now\nPlaylist 22.12.2003:\n- The Ethopians: Train To Skaville\n- Maroon Town: Pound To The Dollar\n- Court Jester\'s Crew: The Mysterious Voyage of Dillfried die Maus\n- Yellow Umbrella: Days Are Numbered\n- The Riffs: Monday Morning\n- The Busters: Friday On My Mind\n- Laurel Aitken: Going Back To The Frontline\n- Wickeda: Me And Bobby Drinking Coffee\n- Piracy: Sudden Heroes\n- Toots & The Maytals: (Take Me Home) Country Roads\n- Wisecräcker: Mucker\n- Tokyo Ska Par
# ...

# %%
def parse_date(line):
    # parses lines like 'Playlist 15.12.2003:' or 'Playlist 3.12.2004 (zu Gast: DJ Bernie (Rudeboy’s Delight)):'
    first_dot_index = line.index('.')
    second_dot_index = line.index('.', first_dot_index+1)
    #print(second_dot_index)
    date = line[9:second_dot_index+5]
    return date

# %%
pl_line = 'Playlist 15.12.2003:'
date = parse_date(pl_line)
print(date)
pl_line = 'Playlist 22.9.2003:'
date = parse_date(pl_line)
print(date)
pl_line = 'Playlist 3.12.2004 (zu Gast: DJ Bernie (Rudeboy’s Delight)):'
date = parse_date(pl_line)
print(date)
# Out:
# 15.12.2003
# 22.9.2003
# 3.12.2004

# %%
def parse_song_line(line):
    # parses lines like '- Lionsclub: The Persuaders'
    # or 'Victor Rice: Fique <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/>'
    line = line[2:]
    NEW_MARK = ' <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/>'
    SKA21_MARK = ' <a href="http://file-under-ska.de/old/ska21/" target="_blank" rel="noopener"><img src="http://ska.one/ska21_16.gif" alt="Track von SKA 21" border="0"/></a>'
    is_new = False
    if (line.endswith(NEW_MARK)):
        is_new = True
        line = line[0 : -len(NEW_MARK)]
    is_ska21 = False
    if (line.endswith(SKA21_MARK)):
        is_ska21 = True
        line = line[0 : -len(SKA21_MARK)]
    both = line.split(": ")
    artist = both[0]
    title = both[1]
    return artist, title, is_new, is_ska21

# %%
line = "- Joe Higgs: I'm The Song That My Enemies Sing"
print(parse_song_line(line))
line = '- Victor Rice: Fique <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/>'
print(parse_song_line(line))
line = '- The MOOD: File Under Ska Special <a href="http://file-under-ska.de/old/ska21/" target="_blank" rel="noopener"><img src="http://ska.one/ska21_16.gif" alt="Track von SKA 21" border="0"/></a>'
print(parse_song_line(line))
# Out:
# ('Joe Higgs', "I'm The Song That My Enemies Sing", False, False)
# ('Victor Rice', 'Fique', True, False)
# ('The MOOD', 'File Under Ska Special', False, True)

# %%
def parse_url(url):
    text = read_url(url)
    text = extract_raw_playlists(text)
    text = replace_junk(text)
    text = norm_linebreaks(text)
    lines = text.split('\n')
    return lines

# %%
def parse_lines(lines):
    songs = list()
    errors = list()
    for line in lines:
        #print("parsing: '" + line + "'")
        if not line:
            #print('Ignoring empty line')
            k=0 # noop
        elif (line.startswith('Playlist')):
            date = parse_date(line)
        elif (line.startswith('- ')):
            artist, title, is_new, is_ska21 = parse_song_line(line)
            songs.append([artist, title, date, is_new, is_ska21])
        else:
            #print("Cannot parse '" + line + '"')
            errors.append(line)
        #print('line: ' + artist + ' / ' + title + ' / ' + date)
    return songs, errors

# %%
def parse_lines(lines, songs, errors):
    for line in lines:
        #print("parsing: '" + line + "'")
        if not line:
            #print('Ignoring empty line')
            k=0 # noop
        elif (line.startswith('Playlist')):
            date = parse_date(line)
        elif (line.startswith('- ')):
            artist, title, is_new, is_ska21 = parse_song_line(line)
            songs.append([artist, title, date, is_new, is_ska21])
        else:
            #print("Cannot parse '" + line + '"')
            errors.append(line)
        #print('line: ' + artist + ' / ' + title + ' / ' + date)

# %%
def parse_playlist(url, all_songs, all_errors):
    text = read_url(url)
    text = extract_raw_playlists(text)
    text = replace_junk(text)
    text = norm_linebreaks(text)
    lines = text.split('\n')
    parse_lines(lines, all_songs, all_errors)

# %%
def go():
    songs = list()
    errors = list()
    parse_playlist('http://ska.one/playlists/playlists-2003/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2004/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2005/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2006/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2007/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2008/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2009/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2010/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2011/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2012/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2013/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2014/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2015/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2016/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists-2017/', songs, errors)
    parse_playlist('http://ska.one/playlists/playlists/', songs, errors)
    return songs, errors

# %%
songs, errors = go()

# %%
errors
# Out:
# ['Vertretungsstunde 21-22 Uhr:',
#  'Vertretungsstunde 21-22 Uhr:',
#  'Vertretungsstunde 19-20 Uhr:',
#  'zu Gast um 20 Uhr: <a href="http://www.los-skalameros.de" target="_blank" rel="noopener">Los Skalameros</a>',
#  "Vertretungsstunde für &#8218;Suchtstation für Musikjunkies':"]

# %%
len(songs)
# Out:
# 9582
