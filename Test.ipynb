# %%
print("hello")
# Out:
# hello

# %%
print(2)
# Out:
# 2

# %%
import pandas as pd

# %%
from urllib.request import urlopen 
import re
def read_url(url): 
    return re.sub('\\s+', ' ', urlopen(url).read().decode())

# %%
playlist_2003_url = 'http://ska.one/playlists/playlists-2003/'
playlist_2003_text = read_url(playlist_2003_url)

# %%
playlist_2003_text
# Out:
# '<!DOCTYPE html> <html lang="de-DE"> <head> <meta charset="UTF-8"> <meta name="viewport" content="width=device-width, initial-scale=1"> <title>Playlists 2003 | File Under Ska</title> <link rel="profile" href="http://gmpg.org/xfn/11"> <link rel="pingback" href="http://ska.one/xmlrpc.php"> <link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' /> <link rel=\'dns-prefetch\' href=\'//s.w.org\' /> <link rel="alternate" type="application/rss+xml" title="File Under Ska &raquo; Feed" href="http://ska.one/feed/" /> <link rel="alternate" type="application/rss+xml" title="File Under Ska &raquo; Kommentar-Feed" href="http://ska.one/comments/feed/" /> <script type="text/javascript"> window._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/2.4\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/2.4\\/svg\\/","svgExt":".svg","source":{"concatemoji":"http:\\/\\/ska.one\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=4.9.5"}}; !function(a,b
# ...

# %%
before_index = playlist_2003_text.index('<p>Playlist')

# %%
before_index
# Out:
# 9687

# %%
after_index = playlist_2003_text.index('</p> </div>')

# %%
after_index
# Out:
# 35249

# %%
c2004 = p2004[p2004.index('<!-- Start -->')+19 : p2004.index('<!-- End -->')-4]

# %%
c2004
# Out:
# '<p>Playlist 17.12.2004:</p> <p>&#8211; Los Placebos: Happy Again<br /> &#8211; Let&#8217;s Go Bowling: Oatmeal For X-Mas<br /> &#8211; Wickeda: Memories<br /> &#8211; Bluekilla: Sunshine Reggae<br /> &#8211; The Ska Flames: Tokyo Shot<br /> &#8211; Tiefenrausch: Der Traum ist aus <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/><br /> &#8211; Lo &amp; The Magnetics: This Town&#8217;s Unbearable <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/><br /> &#8211; MU330: X-Mas Card<br /> &#8211; Markscheider Kunst: Jamaica<br /> &#8211; The Busters: Be Positive<br /> &#8211; Rico: Runaway<br /> &#8211; Tschiggedab: Bad English<br /> &#8211; Slow Gherkin: Hava Nagilah<br /> &#8211; Tiefenrausch: Kleopatra <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/><br /> &#8211; St. Petersburg Ska-Jazz Review: Anarchy In The UK <img class="alignnone size-full wp-image-37" src="http://ska.one/new.gif"/><br /> &#8211; Intensif
# ...
